# %%
import pandas as pd

# %%
data=pd.read_csv("scrappeddata.csv")
dataset=pd.DataFrame(data)

# %%
duplicates=dataset.duplicated()
duplicates
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193282    False
# 193283    False
# 193284    False
# 193285    False
# 193286    False
# Length: 193287, dtype: bool

# %%
count=duplicates.sum()
count
# Out:
# 10508

# %%
datas=dataset.drop_duplicates(keep='first',inplace=True)

# %%
dataset.to_csv("indianspots.csv", index=False)

# %%
data
# Out:
#                                                      Name   Latitude  \
# 0                        GVMC Walkers Park, Thulasi Nagar  17.800739
# 1                                               BHEL Park  17.702312
# 2                                         Prashanthi Park  17.746854
# 3                                                Zen Park  17.724689
# 4                                        Vikas Nagar Park  17.673008
# ...                                                   ...        ...
# 193282  কাছ নদী ও নাগর নদী মিলনস্থল (CONFLUENCE of KAI...  25.662953
# 193283            Mahananda land for shamsher kheera land  26.099410
# 193284                                               Mela  26.186877
# 193285                Zurich agro science integrated farm  25.875447
# 193286                                        Police here  26.007776
#
#         Longitude Rating                                         Categories  \
# 0       83.346711    4.2             park, point_of_interest, establishment
# 1       83.202795    4.1             park, point_of_interest, establishment
# 2       83.266634      4             park, point_of_interest, establishment
# 3       83.315005    4.4             park, point_of_interest, establishment
# 4       83.214204    3.9             park, point_of_interest, establishment
# ...           ...    ...                                                ...
# 193282  88.048741      0  tourist_attraction, point_of_interest, establi...
# 193283  87.878430      0  tourist_attraction, point_of_interest, establi...
# 193284  87.779017    2.3  tourist_attraction, point_of_interest, establi...
# 193285  87.843589      0  tourist_attraction, point_of_interest, establi...
# 193286  87.857791      0  tourist_attraction, point_of_interest, establi...
#
#            Keyword           State       Season        District  \
# 0            parks  Andhra Pradesh       Spring      Anakapalli
# 1            parks  Andhra Pradesh       Spring      Anakapalli
# 2            parks  Andhra Pradesh       Spring      Anakapalli
# 3            parks  Andhra Pradesh       Spring      Anakapalli
# 4            parks  Andhra Pradesh       Spring      Anakapalli
# ...            ...             ...          ...             ...
# 193282  attraction     West Bengal  All Seasons  Uttar Dinajpur
# 193283  attraction     West Bengal  All Seasons  Uttar Dinajpur
# 193284  attraction     West Bengal  All Seasons  Uttar Dinajpur
# 193285  attraction     West Bengal  All Seasons  Uttar Dinajpur
# 193286  attraction     West Bengal  All Seasons  Uttar Dinajpur
#
#         Visitors_Count
# 0                  641
# 1                  133
# 2                  212
# 3                   65
# 4                  408
# ...                ...
# 193282               0
# 193283               0
# 193284               6
# 193285               0
# 193286               0
#
# [193287 rows x 10 columns]
